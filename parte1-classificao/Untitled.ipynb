# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dados = np.random.normal(loc=4, scale=2, size=10000)
dados2=np.random.exponential(1,size=10000)

# %%
dados
# Out:
# array([[7.39069193],
#        [3.46562504],
#        [3.27389985],
#        ...,
#        [5.98992494],
#        [6.15538587],
#        [4.5607074 ]])

# %%
dados=dados.reshape(-1,1)
dados2=dados2.reshape(-1,1)

# %%
sns.kdeplot(dados)
# Out:
# C:\Users\T-Gamer\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\T-Gamer\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\T-Gamer\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
from sklearn.preprocessing import StandardScaler
stnd=StandardScaler()
dados_processed = stnd.fit_transform(dados)
dados2_processed = stnd.fit_transform(dados2)
dir(stnd)
# Out:
# ['__annotations__',
#  '__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__setstate__',
#  '__sizeof__',
#  '__sklearn_clone__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  '_build_request_for_signature',
#  '_check_feature_names',
#  '_check_n_features',
#  '_get_default_requests',
#  '_get_metadata_request',
#  '_get_param_names',
#  '_get_tags',
#  '_more_tags',
#  '_parameter_constraints',
#  '_repr_html_',
#  '_repr_html_inner',
#  '_repr_mimebundle_',
#  '_reset',
#  '_sklearn_auto_wrap_output_keys',
#  '_validate_data',
#  '_validate_params',
#  'copy',
#  'fit',
#  'fit_transform',
#  'get_feature_names_out',
#  'get_metadata_routing',
# ...

# %%
sns.kdeplot(dados2),sns.kdeplot(dados2_processed)
# Out:
# C:\Users\T-Gamer\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\T-Gamer\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# C:\Users\T-Gamer\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1498: FutureWarning: is_categorical_dtype is deprecated and will be removed in a future version. Use isinstance(dtype, CategoricalDtype) instead
#   if pd.api.types.is_categorical_dtype(vector):
# ...

# %%
dados2.mean(),dados2.std()
# Out:
# (0.992972478787524, 0.986636417169928)

# %%
dados2_processed.mean(),dados2_processed.std()
# Out:
# (3.765876499528531e-17, 0.9999999999999998)
